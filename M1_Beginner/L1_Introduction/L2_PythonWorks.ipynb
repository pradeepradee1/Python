# %% [markdown]
# # Interpreter
#
# ## 1 . No Need Compile Python Programs Explicitly
# ## 2 . Internally Python Interpreter will take care that compilation
# ## 3 . If compilation fails, interpreter raised syntax errors
# ## 4 . Once compilation success then PVM(Python Virtual Machine) is responsible to execute

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('L2_PythonWorks1.jpg')
plt.figure(figsize=(6,12))
plt.imshow(img)
