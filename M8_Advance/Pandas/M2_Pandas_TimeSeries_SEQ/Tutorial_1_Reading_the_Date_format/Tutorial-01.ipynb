# %% [markdown]
# # Topic :
# # 1.DatetimeIndex
# # 2.Resampling

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#           Date Close/Last     Volume      Open       High       Low
# 0   09/09/2021    $154.07   57305730   $155.49    $156.11   $153.95
# 1   09/08/2021    $155.11   74420210   $156.98    $157.04  $153.975
# 2   09/07/2021    $156.69   82278260   $154.97    $157.26   $154.39
# 3   09/03/2021     $154.3   57866070   $153.76    $154.63   $153.09
# 4   09/02/2021    $153.65   71171320   $153.87    $154.72    $152.4
# 5   09/01/2021    $152.51   80313710   $152.83    $154.98   $152.34
# 6   08/31/2021    $151.83   86453120   $152.66     $152.8   $151.29
# 7   08/30/2021    $153.12   90956720      $149    $153.49   $148.61
# 8   08/27/2021     $148.6   55802390   $147.48    $148.75   $146.83
# 9   08/26/2021    $147.54   48597200   $148.35    $149.12   $147.51
# 10  08/25/2021    $148.36   58991300   $149.81    $150.32    $147.8
# 11  08/24/2021    $149.62   48606430   $149.45    $150.86   $149.15
# 12  08/23/2021    $149.71   60131810   $148.31    $150.19   $147.89
# ...

# %%
df.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
df = pd.read_csv("data.csv",parse_dates=["Date"])
df
# Out:
#          Date Close/Last     Volume      Open       High       Low
# 0  2021-09-09    $154.07   57305730   $155.49    $156.11   $153.95
# 1  2021-09-08    $155.11   74420210   $156.98    $157.04  $153.975
# 2  2021-09-07    $156.69   82278260   $154.97    $157.26   $154.39
# 3  2021-09-03     $154.3   57866070   $153.76    $154.63   $153.09
# 4  2021-09-02    $153.65   71171320   $153.87    $154.72    $152.4
# 5  2021-09-01    $152.51   80313710   $152.83    $154.98   $152.34
# 6  2021-08-31    $151.83   86453120   $152.66     $152.8   $151.29
# 7  2021-08-30    $153.12   90956720      $149    $153.49   $148.61
# 8  2021-08-27     $148.6   55802390   $147.48    $148.75   $146.83
# 9  2021-08-26    $147.54   48597200   $148.35    $149.12   $147.51
# 10 2021-08-25    $148.36   58991300   $149.81    $150.32    $147.8
# 11 2021-08-24    $149.62   48606430   $149.45    $150.86   $149.15
# 12 2021-08-23    $149.71   60131810   $148.31    $150.19   $147.89
# ...

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Close/Last            object
# Volume                 int64
# Open                  object
# High                  object
# Low                   object
# dtype: object

# %%
df = pd.read_csv("data.csv",parse_dates=["Date"],index_col="Date")
df
# Out:
#            Close/Last     Volume      Open       High       Low
# Date
# 2021-09-09    $154.07   57305730   $155.49    $156.11   $153.95
# 2021-09-08    $155.11   74420210   $156.98    $157.04  $153.975
# 2021-09-07    $156.69   82278260   $154.97    $157.26   $154.39
# 2021-09-03     $154.3   57866070   $153.76    $154.63   $153.09
# 2021-09-02    $153.65   71171320   $153.87    $154.72    $152.4
# 2021-09-01    $152.51   80313710   $152.83    $154.98   $152.34
# 2021-08-31    $151.83   86453120   $152.66     $152.8   $151.29
# 2021-08-30    $153.12   90956720      $149    $153.49   $148.61
# 2021-08-27     $148.6   55802390   $147.48    $148.75   $146.83
# 2021-08-26    $147.54   48597200   $148.35    $149.12   $147.51
# 2021-08-25    $148.36   58991300   $149.81    $150.32    $147.8
# 2021-08-24    $149.62   48606430   $149.45    $150.86   $149.15
# 2021-08-23    $149.71   60131810   $148.31    $150.19   $147.89
# 2021-08-20    $148.19   60549630   $147.44     $148.5   $146.78
# ...

# %%
df.rename(columns={
    "Close/Last" :"Close"
},inplace=True)

# %%
df.index
# Out:
# DatetimeIndex(['2021-09-09', '2021-09-08', '2021-09-07', '2021-09-03',
#                '2021-09-02', '2021-09-01', '2021-08-31', '2021-08-30',
#                '2021-08-27', '2021-08-26', '2021-08-25', '2021-08-24',
#                '2021-08-23', '2021-08-20', '2021-08-19', '2021-08-18',
#                '2021-08-17', '2021-08-16', '2021-08-13', '2021-08-12',
#                '2021-08-11', '2021-08-10'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df["2021-09"]
# Out:
# /tmp/ipykernel_92030/2258506150.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2021-09"]
#               Close    Volume     Open     High       Low
# Date
# 2021-09-09  $154.07  57305730  $155.49  $156.11   $153.95
# 2021-09-08  $155.11  74420210  $156.98  $157.04  $153.975
# 2021-09-07  $156.69  82278260  $154.97  $157.26   $154.39
# 2021-09-03   $154.3  57866070  $153.76  $154.63   $153.09
# 2021-09-02  $153.65  71171320  $153.87  $154.72    $152.4
# 2021-09-01  $152.51  80313710  $152.83  $154.98   $152.34

# %%
df["2021"]
# Out:
# /tmp/ipykernel_92030/2272560262.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2021"]
#               Close     Volume      Open       High       Low
# Date
# 2021-09-09  $154.07   57305730   $155.49    $156.11   $153.95
# 2021-09-08  $155.11   74420210   $156.98    $157.04  $153.975
# 2021-09-07  $156.69   82278260   $154.97    $157.26   $154.39
# 2021-09-03   $154.3   57866070   $153.76    $154.63   $153.09
# 2021-09-02  $153.65   71171320   $153.87    $154.72    $152.4
# 2021-09-01  $152.51   80313710   $152.83    $154.98   $152.34
# 2021-08-31  $151.83   86453120   $152.66     $152.8   $151.29
# 2021-08-30  $153.12   90956720      $149    $153.49   $148.61
# 2021-08-27   $148.6   55802390   $147.48    $148.75   $146.83
# 2021-08-26  $147.54   48597200   $148.35    $149.12   $147.51
# ...

# %%
df["2021-09"].mean()
# Out:
# /tmp/ipykernel_92030/3032509329.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2021-09"].mean()
# /tmp/ipykernel_92030/3032509329.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df["2021-09"].mean()
# Volume    7.055922e+07
# dtype: float64

# %%
df["2021-08-01":"2021-09-01"]
# Out:
#               Close     Volume      Open       High      Low
# Date
# 2021-09-01  $152.51   80313710   $152.83    $154.98  $152.34
# 2021-08-31  $151.83   86453120   $152.66     $152.8  $151.29
# 2021-08-30  $153.12   90956720      $149    $153.49  $148.61
# 2021-08-27   $148.6   55802390   $147.48    $148.75  $146.83
# 2021-08-26  $147.54   48597200   $148.35    $149.12  $147.51
# 2021-08-25  $148.36   58991300   $149.81    $150.32   $147.8
# 2021-08-24  $149.62   48606430   $149.45    $150.86  $149.15
# 2021-08-23  $149.71   60131810   $148.31    $150.19  $147.89
# 2021-08-20  $148.19   60549630   $147.44     $148.5  $146.78
# 2021-08-19   $146.7   86960310   $145.03       $148   $144.5
# 2021-08-18  $146.36   86325990    $149.8    $150.72  $146.15
# 2021-08-17  $150.19   92229740   $150.23    $151.68  $149.09
# 2021-08-16  $151.12  103558800  $148.535    $151.19  $146.47
# 2021-08-13   $149.1   59375010   $148.97  $149.4444  $148.27
# ...

# %% [markdown]
# # Resampling

# %%
df.Volume.resample('M').mean()
# Out:
# Date
# 2021-08-31    7.061463e+07
# 2021-09-30    7.055922e+07
# Freq: M, Name: Volume, dtype: float64

# %%
df.Volume.resample('Y').mean()
# Out:
# Date
# 2021-12-31    7.059952e+07
# Freq: A-DEC, Name: Volume, dtype: float64

# %%
df.Volume.resample('W').mean()
# Out:
# Date
# 2021-08-15    6.266766e+07
# 2021-08-22    8.592489e+07
# 2021-08-29    5.442583e+07
# 2021-09-05    7.735219e+07
# 2021-09-12    7.133473e+07
# Freq: W-SUN, Name: Volume, dtype: float64

# %%
df.Volume.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Notes : Short_cut in notebook
# ##### 1. Select Any function and then press Shift + Tab
# ##### 2. <https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateof

# %%
df.Volume.resample('W').mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Volume.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Volume.resample('Q').mean()
# Out:
# Date
# 2021-09-30    7.059952e+07
# Freq: Q-DEC, Name: Volume, dtype: float64

# %%
df.Volume.resample('Q').std()
# Out:
# Date
# 2021-09-30    1.615228e+07
# Freq: Q-DEC, Name: Volume, dtype: float64
