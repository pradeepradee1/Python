# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data=np.random.randint(99999, 99999999, size=(10000000,14)),
    columns=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14'])
df
# Out:
#                C1        C2        C3        C4        C5        C6        C7  \
# 0        11698985  33850934  31040153   6429927  79023476  48072112  41154500
# 1        76436722  32909842  41802963  68183985  81326310  62878454  30619396
# 2        70947377  86132646  26191232  57067679  63027266  65211833  10988182
# 3        26213349  40449906  27369580  18328508  71545108  72350661  80573000
# 4        76416724  64866797   7953493  34907073   2729448  48507182  36325426
# ...           ...       ...       ...       ...       ...       ...       ...
# 9999995  29504730  76281334  81761789  22996785   7270041  79156002  39010428
# 9999996  56761744  18851727  57711694  66545938  29370045  38120301  70164148
# 9999997  99301461   1789513  11238829  17299262  14814502  28046284  42901914
# 9999998  37867443  63653038  30024624  97143355   6498950  80360535  68484741
# 9999999  93179280   4806673  50379555  75552834  34351607  70751544  44586394
#
# ...

# %%
df['C15'] = pd.util.testing.rands_array(5,10000000)
df.to_csv("huge_data.csv",index=False)
# Out:
# /home/pradeep.k@zucisystems.com/.local/share/virtualenvs/DataAnalysis-7lrpAe9F/lib/python3.8/site-packages/pandas/util/__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing

# %%
import time
start = time.time()
df = pd.read_csv('huge_data.csv')
end = time.time()
print("Read csv without chunks: ",(end-start),"sec")
# Out:
# Read csv without chunks:  13.042296886444092 sec

# %%
df.head(1)
# Out:
#          C1        C2        C3       C4        C5        C6        C7  \
# 0  11698985  33850934  31040153  6429927  79023476  48072112  41154500
#
#          C8        C9       C10       C11       C12       C13       C14    C15
# 0  19871487  91890268  70260703  49444497  76882107  13952214  50710199  xrRV9

# %%
df.shape
# Out:
# (10000000, 15)

# %%
start = time.time()
#read data in chunks of 10 million rows at a time
chunkdf = pd.read_csv('huge_data.csv',chunksize=100000)
end = time.time()
print("Read csv with chunks: ",(end-start),"sec")
# pd_df = pd.concat(chunk)
# Out:
# Read csv with chunks:  0.0025081634521484375 sec

# %%
from pprint import pprint
chunkdf

# %%
pprint(chunkdf)

# %%
a=0
for i in chunkdf:
    a+=1
    pprint(i.shape)
print(a)
#     break
# Out:
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# (100000, 15)
# ...
